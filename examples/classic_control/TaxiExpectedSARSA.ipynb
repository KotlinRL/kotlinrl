// %% [markdown]
// ## Expected SARSA example of Taxi

// %%
USE {
    repositories {
        mavenCentral()
        maven("https://central.sonatype.com/repository/maven-snapshots/")
    }
    dependencies {
        implementation("io.github.kotlinrl:integration:0.1.0-SNAPSHOT")
        implementation("io.github.kotlinrl:tabular:0.1.0-SNAPSHOT")
        implementation("io.github.kotlinrl:envs:0.1.0-SNAPSHOT")
        implementation("io.github.kotlinrl:rendering:0.1.0-SNAPSHOT")
    }
}

// %%
import io.github.kotlinrl.core.*
import io.github.kotlinrl.integration.gymnasium.*
import io.github.kotlinrl.integration.gymnasium.GymnasiumEnvs.*
import io.github.kotlinrl.rendering.*
import io.github.kotlinrl.tabular.*
import org.jetbrains.kotlinx.kandy.letsplot.export.*
import org.jetbrains.kotlinx.multik.api.*
import org.jetbrains.kotlinx.multik.api.io.*
import org.jetbrains.kotlinx.multik.ndarray.data.*
import java.io.*

// %%
val maxStepsPerEpisode = 205
val trainingEpisodes = 5_000
val testEpisodes = 50
val initialEpsilon = 0.8
val epsilonDecayRate = 0.000177
val minEpsilon = 0.0
val alpha = 0.5
val gamma = 0.99
val fileName = "TaxiExpectedSARSA.npy"

// %%
val env = gymnasium.make<CliffWalkingEnv>(Taxi_v3, render = true)

var trainingQtable: QTable = mk.d2array(500, 6) { 0.0 }

val (epsilonSchedule, epsilonDecrement) = ParameterSchedule.linearDecay(
    initialValue = initialEpsilon,
    minValue = minEpsilon,
    decayRate = epsilonDecayRate,
    callback = { episode, parameter ->
        if (episode % 100 == 0) {
            println("Episode: $episode, Epsilon: $parameter")
        }
    }
)
// Out:
// 2025-09-18T08:57:42.835211Z Execution of code 'val env = gymnasium....' ERROR Log4j2 could not find a logging implementation. Please add log4j-core to the classpath. Using SimpleLogger to log to the console...

// %%
val trainer = episodicTrainer(
    env = env,
    agent = learningAgent(
        id = "training",
        algorithm = ExpectedSARSA(
            Q = trainingQtable,
            epsilon = epsilonSchedule,
            alpha = ParameterSchedule.constant(alpha),
            gamma = gamma,
        )
    ),
    maxStepsPerEpisode = maxStepsPerEpisode,
    successfulTermination = { it.terminated },
    callbacks = listOf(
        printEpisodeStart(100),
        onEpisodeEnd {
            epsilonDecrement()
            if (it.totalEpisodes % 1_000 == 0) {
                val goalSuccessCount = TrainingResult(it.episodeStats.takeLast(1_000)).totalGoalSuccessCount
                println("Current goal success count: $goalSuccessCount, over the last 1000 episodes")
            }
        }
    )
)
println("Starting training")
val training = trainer.train(maxEpisodes(trainingEpisodes))
mk.writeNPY(fileName, trainingQtable)
// Out:
// Starting training
// Episode 1 truncated=true
// Episode 2 truncated=true
// Episode 3 truncated=true
// Episode 4 truncated=true
// Episode 5 truncated=true
// Episode 7 truncated=true
// Episode 8 truncated=true
// Episode 9 truncated=true
// Episode 10 truncated=true
// Episode 11 truncated=true
// Episode 12 truncated=true
// Episode 13 truncated=true
// Episode 14 truncated=true
// Episode 15 truncated=true
// Episode 16 truncated=true
// Episode 17 truncated=true
// Episode 18 truncated=true
// Episode 19 truncated=true
// Episode 21 truncated=true
// Episode 22 truncated=true
// Episode 23 truncated=true
// Episode 24 truncated=true
// Episode 25 truncated=true
// Episode 26 truncated=true
// Episode 640 truncated=true
// Episode 644 truncated=true
// Episode 699 truncated=true
// Starting episode 700
// Episode: 700, Epsilon: Parameter(current=0.6761000000000121, previous=0.6762770000000121, minValue=0.0)
// Episode 736 truncated=true
// Episode 748 truncated=true
// Starting episode 800
// Episode: 800, Epsilon: Parameter(current=0.6584000000000139, previous=0.6585770000000138, minValue=0.0)
// Episode 834 truncated=true
// Episode 855 truncated=true
// Starting episode 900
// Episode: 900, Epsilon: Parameter(current=0.6407000000000156, previous=0.6408770000000156, minValue=0.0)
// Starting episode 1000
// Episode: 1000, Epsilon: Parameter(current=0.6230000000000173, previous=0.6231770000000173, minValue=0.0)
// Starting episode 1100
// Episode: 1100, Epsilon: Parameter(current=0.605300000000019, previous=0.605477000000019, minValue=0.0)
// Starting episode 1200
// Episode: 1200, Epsilon: Parameter(current=0.5876000000000208, previous=0.5877770000000208, minValue=0.0)
// Starting episode 1300
// Episode: 1300, Epsilon: Parameter(current=0.5699000000000225, previous=0.5700770000000225, minValue=0.0)
// Starting episode 1400
// Episode: 1400, Epsilon: Parameter(current=0.5522000000000242, previous=0.5523770000000242, minValue=0.0)
// Starting episode 1500
// Episode: 1500, Epsilon: Parameter(current=0.534500000000026, previous=0.5346770000000259, minValue=0.0)
// Starting episode 1600
// Episode: 1600, Epsilon: Parameter(current=0.5168000000000277, previous=0.5169770000000277, minValue=0.0)
// Starting episode 1700
// Episode: 1700, Epsilon: Parameter(current=0.4991000000000294, previous=0.4992770000000294, minValue=0.0)
// Starting episode 1800
// Episode: 1800, Epsilon: Parameter(current=0.48140000000003114, previous=0.4815770000000311, minValue=0.0)
// Starting episode 1900
// Episode: 1900, Epsilon: Parameter(current=0.46370000000003286, previous=0.46387700000003285, minValue=0.0)
// Starting episode 2000
// Episode: 2000, Epsilon: Parameter(current=0.4460000000000346, previous=0.4461770000000346, minValue=0.0)
// Starting episode 2100
// Episode: 2100, Epsilon: Parameter(current=0.4283000000000363, previous=0.4284770000000363, minValue=0.0)
// Starting episode 2200
// Episode: 2200, Epsilon: Parameter(current=0.41060000000003805, previous=0.41077700000003803, minValue=0.0)
// Starting episode 2300
// Episode: 2300, Epsilon: Parameter(current=0.3929000000000398, previous=0.39307700000003976, minValue=0.0)
// Starting episode 2400
// Episode: 2400, Epsilon: Parameter(current=0.3752000000000415, previous=0.3753770000000415, minValue=0.0)
// Starting episode 2500
// Episode: 2500, Epsilon: Parameter(current=0.3575000000000432, previous=0.3576770000000432, minValue=0.0)
// Starting episode 2600
// Episode: 2600, Epsilon: Parameter(current=0.33980000000004495, previous=0.33997700000004494, minValue=0.0)
// Starting episode 2700
// Episode: 2700, Epsilon: Parameter(current=0.3221000000000467, previous=0.32227700000004667, minValue=0.0)
// Starting episode 2800
// Episode: 2800, Epsilon: Parameter(current=0.3044000000000484, previous=0.3045770000000484, minValue=0.0)
// Starting episode 2900
// Episode: 2900, Epsilon: Parameter(current=0.28670000000005014, previous=0.2868770000000501, minValue=0.0)
// Starting episode 3000
// Episode: 3000, Epsilon: Parameter(current=0.26900000000005186, previous=0.26917700000005185, minValue=0.0)
// Starting episode 3100
// Episode: 3100, Epsilon: Parameter(current=0.2513000000000536, previous=0.2514770000000536, minValue=0.0)
// Starting episode 3200
// Episode: 3200, Epsilon: Parameter(current=0.23360000000005274, previous=0.23377700000005275, minValue=0.0)
// Starting episode 3300
// Episode: 3300, Epsilon: Parameter(current=0.2159000000000517, previous=0.2160770000000517, minValue=0.0)
// Starting episode 3400
// Episode: 3400, Epsilon: Parameter(current=0.19820000000005064, previous=0.19837700000005065, minValue=0.0)
// Starting episode 3500
// Episode: 3500, Epsilon: Parameter(current=0.1805000000000496, previous=0.1806770000000496, minValue=0.0)
// Starting episode 3600
// Episode: 3600, Epsilon: Parameter(current=0.16280000000004854, previous=0.16297700000004856, minValue=0.0)
// Starting episode 3700
// Episode: 3700, Epsilon: Parameter(current=0.1451000000000475, previous=0.1452770000000475, minValue=0.0)
// Starting episode 3800
// Episode: 3800, Epsilon: Parameter(current=0.12740000000004645, previous=0.12757700000004646, minValue=0.0)
// Starting episode 3900
// Episode: 3900, Epsilon: Parameter(current=0.10970000000004661, previous=0.1098770000000466, minValue=0.0)
// Starting episode 4000
// Episode: 4000, Epsilon: Parameter(current=0.09200000000004695, previous=0.09217700000004694, minValue=0.0)
// Starting episode 4100
// Episode: 4100, Epsilon: Parameter(current=0.07430000000004729, previous=0.07447700000004728, minValue=0.0)
// Starting episode 4200
// Episode: 4200, Epsilon: Parameter(current=0.056600000000047626, previous=0.05677700000004762, minValue=0.0)
// Starting episode 4300
// Episode: 4300, Epsilon: Parameter(current=0.038900000000047966, previous=0.03907700000004796, minValue=0.0)
// Starting episode 4400
// Episode: 4400, Epsilon: Parameter(current=0.021200000000048107, previous=0.021377000000048108, minValue=0.0)
// Starting episode 4500
// Episode: 4500, Epsilon: Parameter(current=0.0035000000000481, previous=0.0036770000000481, minValue=0.0)
// Starting episode 4600
// Episode: 4600, Epsilon: Parameter(current=0.0, previous=0.0, minValue=0.0)
// Starting episode 4700
// Episode: 4700, Epsilon: Parameter(current=0.0, previous=0.0, minValue=0.0)
// Starting episode 4800
// Episode: 4800, Epsilon: Parameter(current=0.0, previous=0.0, minValue=0.0)
// Starting episode 4900
// Episode: 4900, Epsilon: Parameter(current=0.0, previous=0.0, minValue=0.0)
// Starting episode 5000
// Episode: 5000, Epsilon: Parameter(current=0.0, previous=0.0, minValue=0.0)
// Max episodes reached: 5000

// %%
val testingQtable = mk.readNPY<Double, D2>(fileName).asD2Array()

// %%
val recordEnv = RecordVideo(env = env, folder = "videos/taxi_expected_sarsa", testEpisodes / 3)
val tester = episodicTrainer(
    env = recordEnv,
    agent = policyAgent(
        id = "testing",
        policy = testingQtable.greedy()
    ),
    maxStepsPerEpisode = maxStepsPerEpisode,
    successfulTermination = { it.terminated },
    callbacks = listOf(
        printEpisodeStart(10)
    )
)
println("Starting testing")
val test = tester.train(maxEpisodes(testEpisodes))
// Out:
// Starting testing
// Starting episode 10
// Starting episode 20
// Starting episode 30
// Starting episode 40
// Starting episode 50
// Max episodes reached: 50

// %%
println("Training average reward: ${training.totalAverageReward}")
println("Test average reward: ${test.totalAverageReward}")

displayVideos(recordEnv.folder)
// Out:
// Training average reward: -82.3206
// Test average reward: 8.28
